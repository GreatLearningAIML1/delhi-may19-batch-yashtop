# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
file = "/content/drive/My Drive/PGML/labexternal-residency-I/Iris.csv"
Iris = pd.read_csv(file)
#changing column due to spaces in key
Iris.rename(columns={'Sepal Length (in cm)': 'SepalLength(incm)', 'Sepal Width in (cm)': 'SepalWidthin(cm)','Petal length (in cm)':'Petallength(incm)','Petal width (in cm)':'Petalwidth(incm)'},inplace=True)
Iris
# Out:
#      SepalLength(incm)  SepalWidthin(cm)  ...  Petalwidth(incm)           Class
# 0                  5.1               3.5  ...               0.2     Iris-setosa
# 1                  4.9               3.0  ...               0.2     Iris-setosa
# 2                  4.7               3.2  ...               0.2     Iris-setosa
# 3                  4.6               3.1  ...               0.2     Iris-setosa
# 4                  5.0               3.6  ...               0.2     Iris-setosa
# 5                  5.4               3.9  ...               0.4     Iris-setosa
# 6                  4.6               3.4  ...               0.3     Iris-setosa
# 7                  5.0               3.4  ...               0.2     Iris-setosa
# 8                  4.4               2.9  ...               0.2     Iris-setosa
# 9                  4.9               3.1  ...               0.1     Iris-setosa
# 10                 5.4               3.7  ...               0.2     Iris-setosa
# 11                 4.8               3.4  ...               0.2     Iris-setosa
# 12                 4.8               3.0  ...               0.1     Iris-setosa
# 13                 4.3               3.0  ...               0.1     Iris-setosa
# 14                 5.8               4.0  ...               0.2     Iris-setosa
# 15                 5.7               4.4  ...               0.4     Iris-setosa
# 16                 5.4               3.9  ...               0.4     Iris-setosa
# 17                 5.1               3.5  ...               0.3     Iris-setosa
# 18                 5.7               3.8  ...               0.3     Iris-setosa
# 19                 5.1               3.8  ...               0.3     Iris-setosa
# 20                 5.4               3.4  ...               0.2     Iris-setosa
# 21                 5.1               3.7  ...               0.4     Iris-setosa
# 22                 4.6               3.6  ...               0.2     Iris-setosa
# 23                 5.1               3.3  ...               0.5     Iris-setosa
# 24                 4.8               3.4  ...               0.2     Iris-setosa
# 25                 5.0               3.0  ...               0.2     Iris-setosa
# 26                 5.0               3.4  ...               0.4     Iris-setosa
# 27                 5.2               3.5  ...               0.2     Iris-setosa
# 28                 5.2               3.4  ...               0.2     Iris-setosa
# 29                 4.7               3.2  ...               0.2     Iris-setosa
# ..                 ...               ...  ...               ...             ...
# 120                6.9               3.2  ...               2.3  Iris-virginica
# 121                5.6               2.8  ...               2.0  Iris-virginica
# 122                7.7               2.8  ...               2.0  Iris-virginica
# 123                6.3               2.7  ...               1.8  Iris-virginica
# 124                6.7               3.3  ...               2.1  Iris-virginica
# 125                7.2               3.2  ...               1.8  Iris-virginica
# 126                6.2               2.8  ...               1.8  Iris-virginica
# 127                6.1               3.0  ...               1.8  Iris-virginica
# 128                6.4               2.8  ...               2.1  Iris-virginica
# 129                7.2               3.0  ...               1.6  Iris-virginica
# 130                7.4               2.8  ...               1.9  Iris-virginica
# 131                7.9               3.8  ...               2.0  Iris-virginica
# 132                6.4               2.8  ...               2.2  Iris-virginica
# 133                6.3               2.8  ...               1.5  Iris-virginica
# 134                6.1               2.6  ...               1.4  Iris-virginica
# 135                7.7               3.0  ...               2.3  Iris-virginica
# 136                6.3               3.4  ...               2.4  Iris-virginica
# 137                6.4               3.1  ...               1.8  Iris-virginica
# 138                6.0               3.0  ...               1.8  Iris-virginica
# 139                6.9               3.1  ...               2.1  Iris-virginica
# 140                6.7               3.1  ...               2.4  Iris-virginica
# 141                6.9               3.1  ...               2.3  Iris-virginica
# 142                5.8               2.7  ...               1.9  Iris-virginica
# 143                6.8               3.2  ...               2.3  Iris-virginica
# 144                6.7               3.3  ...               2.5  Iris-virginica
# 145                6.7               3.0  ...               2.3  Iris-virginica
# 146                6.3               2.5  ...               1.9  Iris-virginica
# 147                6.5               3.0  ...               2.0  Iris-virginica
# 148                6.2               3.4  ...               2.3  Iris-virginica
# 149                5.9               3.0  ...               1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
Iris.dtypes
# Out:
# SepalLength(incm)    float64
# SepalWidthin(cm)     float64
# Petallength(incm)    float64
# Petalwidth(incm)     float64
# Class                 object
# dtype: object

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
Iris.head(10)
# Out:
#    SepalLength(incm)  SepalWidthin(cm)  ...  Petalwidth(incm)        Class
# 0                5.1               3.5  ...               0.2  Iris-setosa
# 1                4.9               3.0  ...               0.2  Iris-setosa
# 2                4.7               3.2  ...               0.2  Iris-setosa
# 3                4.6               3.1  ...               0.2  Iris-setosa
# 4                5.0               3.6  ...               0.2  Iris-setosa
# 5                5.4               3.9  ...               0.4  Iris-setosa
# 6                4.6               3.4  ...               0.3  Iris-setosa
# 7                5.0               3.4  ...               0.2  Iris-setosa
# 8                4.4               2.9  ...               0.2  Iris-setosa
# 9                4.9               3.1  ...               0.1  Iris-setosa
#
# [10 rows x 5 columns]

# %% [markdown]
# ### Find the shape of the dataset

# %%
Iris.tail(10)
# Out:
#      SepalLength(incm)  SepalWidthin(cm)  ...  Petalwidth(incm)           Class
# 140                6.7               3.1  ...               2.4  Iris-virginica
# 141                6.9               3.1  ...               2.3  Iris-virginica
# 142                5.8               2.7  ...               1.9  Iris-virginica
# 143                6.8               3.2  ...               2.3  Iris-virginica
# 144                6.7               3.3  ...               2.5  Iris-virginica
# 145                6.7               3.0  ...               2.3  Iris-virginica
# 146                6.3               2.5  ...               1.9  Iris-virginica
# 147                6.5               3.0  ...               2.0  Iris-virginica
# 148                6.2               3.4  ...               2.3  Iris-virginica
# 149                5.9               3.0  ...               1.8  Iris-virginica
#
# [10 rows x 5 columns]

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
Iris.set_index(Iris.columns[0],inplace=True)
Iris
# Out:
#                    SepalWidthin(cm)  ...           Class
# SepalLength(incm)                    ...
# 5.1                             3.5  ...     Iris-setosa
# 4.9                             3.0  ...     Iris-setosa
# 4.7                             3.2  ...     Iris-setosa
# 4.6                             3.1  ...     Iris-setosa
# 5.0                             3.6  ...     Iris-setosa
# 5.4                             3.9  ...     Iris-setosa
# 4.6                             3.4  ...     Iris-setosa
# 5.0                             3.4  ...     Iris-setosa
# 4.4                             2.9  ...     Iris-setosa
# 4.9                             3.1  ...     Iris-setosa
# 5.4                             3.7  ...     Iris-setosa
# 4.8                             3.4  ...     Iris-setosa
# 4.8                             3.0  ...     Iris-setosa
# 4.3                             3.0  ...     Iris-setosa
# 5.8                             4.0  ...     Iris-setosa
# 5.7                             4.4  ...     Iris-setosa
# 5.4                             3.9  ...     Iris-setosa
# 5.1                             3.5  ...     Iris-setosa
# 5.7                             3.8  ...     Iris-setosa
# 5.1                             3.8  ...     Iris-setosa
# 5.4                             3.4  ...     Iris-setosa
# 5.1                             3.7  ...     Iris-setosa
# 4.6                             3.6  ...     Iris-setosa
# 5.1                             3.3  ...     Iris-setosa
# 4.8                             3.4  ...     Iris-setosa
# 5.0                             3.0  ...     Iris-setosa
# 5.0                             3.4  ...     Iris-setosa
# 5.2                             3.5  ...     Iris-setosa
# 5.2                             3.4  ...     Iris-setosa
# 4.7                             3.2  ...     Iris-setosa
# ...                             ...  ...             ...
# 6.9                             3.2  ...  Iris-virginica
# 5.6                             2.8  ...  Iris-virginica
# 7.7                             2.8  ...  Iris-virginica
# 6.3                             2.7  ...  Iris-virginica
# 6.7                             3.3  ...  Iris-virginica
# 7.2                             3.2  ...  Iris-virginica
# 6.2                             2.8  ...  Iris-virginica
# 6.1                             3.0  ...  Iris-virginica
# 6.4                             2.8  ...  Iris-virginica
# 7.2                             3.0  ...  Iris-virginica
# 7.4                             2.8  ...  Iris-virginica
# 7.9                             3.8  ...  Iris-virginica
# 6.4                             2.8  ...  Iris-virginica
# 6.3                             2.8  ...  Iris-virginica
# 6.1                             2.6  ...  Iris-virginica
# 7.7                             3.0  ...  Iris-virginica
# 6.3                             3.4  ...  Iris-virginica
# 6.4                             3.1  ...  Iris-virginica
# 6.0                             3.0  ...  Iris-virginica
# 6.9                             3.1  ...  Iris-virginica
# 6.7                             3.1  ...  Iris-virginica
# 6.9                             3.1  ...  Iris-virginica
# 5.8                             2.7  ...  Iris-virginica
# 6.8                             3.2  ...  Iris-virginica
# 6.7                             3.3  ...  Iris-virginica
# 6.7                             3.0  ...  Iris-virginica
# 6.3                             2.5  ...  Iris-virginica
# 6.5                             3.0  ...  Iris-virginica
# 6.2                             3.4  ...  Iris-virginica
# 5.9                             3.0  ...  Iris-virginica
#
# [150 rows x 4 columns]

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
Iris.iloc[:,2]
# Out:
# SepalLength(incm)
# 5.1    0.2
# 4.9    0.2
# 4.7    0.2
# 4.6    0.2
# 5.0    0.2
# 5.4    0.4
# 4.6    0.3
# 5.0    0.2
# 4.4    0.2
# 4.9    0.1
# 5.4    0.2
# 4.8    0.2
# 4.8    0.1
# 4.3    0.1
# 5.8    0.2
# 5.7    0.4
# 5.4    0.4
# 5.1    0.3
# 5.7    0.3
# 5.1    0.3
# 5.4    0.2
# 5.1    0.4
# 4.6    0.2
# 5.1    0.5
# 4.8    0.2
# 5.0    0.2
# 5.0    0.4
# 5.2    0.2
# 5.2    0.2
# 4.7    0.2
#       ...
# 6.9    2.3
# 5.6    2.0
# 7.7    2.0
# 6.3    1.8
# 6.7    2.1
# 7.2    1.8
# 6.2    1.8
# 6.1    1.8
# 6.4    2.1
# 7.2    1.6
# 7.4    1.9
# 7.9    2.0
# 6.4    2.2
# 6.3    1.5
# 6.1    1.4
# 7.7    2.3
# 6.3    2.4
# 6.4    1.8
# 6.0    1.8
# 6.9    2.1
# 6.7    2.4
# 6.9    2.3
# 5.8    1.9
# 6.8    2.3
# 6.7    2.5
# 6.7    2.3
# 6.3    1.9
# 6.5    2.0
# 6.2    2.3
# 5.9    1.8
# Name: Petalwidth(incm), Length: 150, dtype: float64

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
Iris.iloc[:10, 0:1]
# Out:
#                    SepalWidthin(cm)
# SepalLength(incm)
# 5.1                             3.5
# 4.9                             3.0
# 4.7                             3.2
# 4.6                             3.1
# 5.0                             3.6
# 5.4                             3.9
# 4.6                             3.4
# 5.0                             3.4
# 4.4                             2.9
# 4.9                             3.1

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
Iris[Iris['Class']=="Iris-setosa"]
# Out:
#                    SepalWidthin(cm)  ...        Class
# SepalLength(incm)                    ...
# 5.1                             3.5  ...  Iris-setosa
# 4.9                             3.0  ...  Iris-setosa
# 4.7                             3.2  ...  Iris-setosa
# 4.6                             3.1  ...  Iris-setosa
# 5.0                             3.6  ...  Iris-setosa
# 5.4                             3.9  ...  Iris-setosa
# 4.6                             3.4  ...  Iris-setosa
# 5.0                             3.4  ...  Iris-setosa
# 4.4                             2.9  ...  Iris-setosa
# 4.9                             3.1  ...  Iris-setosa
# 5.4                             3.7  ...  Iris-setosa
# 4.8                             3.4  ...  Iris-setosa
# 4.8                             3.0  ...  Iris-setosa
# 4.3                             3.0  ...  Iris-setosa
# 5.8                             4.0  ...  Iris-setosa
# 5.7                             4.4  ...  Iris-setosa
# 5.4                             3.9  ...  Iris-setosa
# 5.1                             3.5  ...  Iris-setosa
# 5.7                             3.8  ...  Iris-setosa
# 5.1                             3.8  ...  Iris-setosa
# 5.4                             3.4  ...  Iris-setosa
# 5.1                             3.7  ...  Iris-setosa
# 4.6                             3.6  ...  Iris-setosa
# 5.1                             3.3  ...  Iris-setosa
# 4.8                             3.4  ...  Iris-setosa
# 5.0                             3.0  ...  Iris-setosa
# 5.0                             3.4  ...  Iris-setosa
# 5.2                             3.5  ...  Iris-setosa
# 5.2                             3.4  ...  Iris-setosa
# 4.7                             3.2  ...  Iris-setosa
# 4.8                             3.1  ...  Iris-setosa
# 5.4                             3.4  ...  Iris-setosa
# 5.2                             4.1  ...  Iris-setosa
# 5.5                             4.2  ...  Iris-setosa
# 4.9                             3.1  ...  Iris-setosa
# 5.0                             3.2  ...  Iris-setosa
# 5.5                             3.5  ...  Iris-setosa
# 4.9                             3.1  ...  Iris-setosa
# 4.4                             3.0  ...  Iris-setosa
# 5.1                             3.4  ...  Iris-setosa
# 5.0                             3.5  ...  Iris-setosa
# 4.5                             2.3  ...  Iris-setosa
# 4.4                             3.2  ...  Iris-setosa
# 5.0                             3.5  ...  Iris-setosa
# 5.1                             3.8  ...  Iris-setosa
# 4.8                             3.0  ...  Iris-setosa
# 5.1                             3.8  ...  Iris-setosa
# 4.6                             3.2  ...  Iris-setosa
# 5.3                             3.7  ...  Iris-setosa
# 5.0                             3.3  ...  Iris-setosa
#
# [50 rows x 4 columns]

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
#there were key error was coming so im giving refernce using column 
Iris["SepalExtra"] = Iris.index * Iris['SepalWidthin(cm)']
Iris
# Out:
#                    SepalWidthin(cm)  ...  SepalExtra
# SepalLength(incm)                    ...
# 5.1                             3.5  ...       17.85
# 4.9                             3.0  ...       14.70
# 4.7                             3.2  ...       15.04
# 4.6                             3.1  ...       14.26
# 5.0                             3.6  ...       18.00
# 5.4                             3.9  ...       21.06
# 4.6                             3.4  ...       15.64
# 5.0                             3.4  ...       17.00
# 4.4                             2.9  ...       12.76
# 4.9                             3.1  ...       15.19
# 5.4                             3.7  ...       19.98
# 4.8                             3.4  ...       16.32
# 4.8                             3.0  ...       14.40
# 4.3                             3.0  ...       12.90
# 5.8                             4.0  ...       23.20
# 5.7                             4.4  ...       25.08
# 5.4                             3.9  ...       21.06
# 5.1                             3.5  ...       17.85
# 5.7                             3.8  ...       21.66
# 5.1                             3.8  ...       19.38
# 5.4                             3.4  ...       18.36
# 5.1                             3.7  ...       18.87
# 4.6                             3.6  ...       16.56
# 5.1                             3.3  ...       16.83
# 4.8                             3.4  ...       16.32
# 5.0                             3.0  ...       15.00
# 5.0                             3.4  ...       17.00
# 5.2                             3.5  ...       18.20
# 5.2                             3.4  ...       17.68
# 4.7                             3.2  ...       15.04
# ...                             ...  ...         ...
# 6.9                             3.2  ...       22.08
# 5.6                             2.8  ...       15.68
# 7.7                             2.8  ...       21.56
# 6.3                             2.7  ...       17.01
# 6.7                             3.3  ...       22.11
# 7.2                             3.2  ...       23.04
# 6.2                             2.8  ...       17.36
# 6.1                             3.0  ...       18.30
# 6.4                             2.8  ...       17.92
# 7.2                             3.0  ...       21.60
# 7.4                             2.8  ...       20.72
# 7.9                             3.8  ...       30.02
# 6.4                             2.8  ...       17.92
# 6.3                             2.8  ...       17.64
# 6.1                             2.6  ...       15.86
# 7.7                             3.0  ...       23.10
# 6.3                             3.4  ...       21.42
# 6.4                             3.1  ...       19.84
# 6.0                             3.0  ...       18.00
# 6.9                             3.1  ...       21.39
# 6.7                             3.1  ...       20.77
# 6.9                             3.1  ...       21.39
# 5.8                             2.7  ...       15.66
# 6.8                             3.2  ...       21.76
# 6.7                             3.3  ...       22.11
# 6.7                             3.0  ...       20.10
# 6.3                             2.5  ...       15.75
# 6.5                             3.0  ...       19.50
# 6.2                             3.4  ...       21.08
# 5.9                             3.0  ...       17.70
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
mn = Iris.loc[:, Iris.columns != 'Class'].mean()
vr = Iris.loc[:, Iris.columns != 'Class'].var()
print(mn,vr)
# Out:
# SepalWidthin(cm)      3.054000
# Petallength(incm)     3.758667
# Petalwidth(incm)      1.198667
# SepalExtra           17.806533
# dtype: float64 SepalWidthin(cm)      0.188004
# Petallength(incm)     3.113179
# Petalwidth(incm)      0.582414
# SepalExtra           11.348090
# dtype: float64

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
def printDfVal(p1,p2):
  print(p1,p2)
  
printDfVal(Iris.index[4],Iris['SepalWidthin(cm)'].iloc[4])
# Out:
# 5.0 3.6

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
rangeV = Iris.loc[:, Iris.columns != 'Class'].max() - Iris.loc[:, Iris.columns != 'Class'].min()
rangeV
# Out:
# SepalWidthin(cm)      2.40
# Petallength(incm)     5.90
# Petalwidth(incm)      2.40
# SepalExtra           20.02
# dtype: float64

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
Iris.sort_values('Petalwidth(incm)')
# Out:
#      SepalLength(incm)  SepalWidthin(cm)  ...  Petalwidth(incm)           Class
# 32                 5.2               4.1  ...               0.1     Iris-setosa
# 13                 4.3               3.0  ...               0.1     Iris-setosa
# 37                 4.9               3.1  ...               0.1     Iris-setosa
# 9                  4.9               3.1  ...               0.1     Iris-setosa
# 12                 4.8               3.0  ...               0.1     Iris-setosa
# 34                 4.9               3.1  ...               0.1     Iris-setosa
# 0                  5.1               3.5  ...               0.2     Iris-setosa
# 27                 5.2               3.5  ...               0.2     Iris-setosa
# 28                 5.2               3.4  ...               0.2     Iris-setosa
# 29                 4.7               3.2  ...               0.2     Iris-setosa
# 30                 4.8               3.1  ...               0.2     Iris-setosa
# 33                 5.5               4.2  ...               0.2     Iris-setosa
# 36                 5.5               3.5  ...               0.2     Iris-setosa
# 38                 4.4               3.0  ...               0.2     Iris-setosa
# 39                 5.1               3.4  ...               0.2     Iris-setosa
# 42                 4.4               3.2  ...               0.2     Iris-setosa
# 46                 5.1               3.8  ...               0.2     Iris-setosa
# 47                 4.6               3.2  ...               0.2     Iris-setosa
# 48                 5.3               3.7  ...               0.2     Iris-setosa
# 49                 5.0               3.3  ...               0.2     Iris-setosa
# 25                 5.0               3.0  ...               0.2     Iris-setosa
# 24                 4.8               3.4  ...               0.2     Iris-setosa
# 35                 5.0               3.2  ...               0.2     Iris-setosa
# 3                  4.6               3.1  ...               0.2     Iris-setosa
# 2                  4.7               3.2  ...               0.2     Iris-setosa
# 7                  5.0               3.4  ...               0.2     Iris-setosa
# 8                  4.4               2.9  ...               0.2     Iris-setosa
# 10                 5.4               3.7  ...               0.2     Iris-setosa
# 4                  5.0               3.6  ...               0.2     Iris-setosa
# 11                 4.8               3.4  ...               0.2     Iris-setosa
# ..                 ...               ...  ...               ...             ...
# 111                6.4               2.7  ...               1.9  Iris-virginica
# 121                5.6               2.8  ...               2.0  Iris-virginica
# 122                7.7               2.8  ...               2.0  Iris-virginica
# 147                6.5               3.0  ...               2.0  Iris-virginica
# 113                5.7               2.5  ...               2.0  Iris-virginica
# 131                7.9               3.8  ...               2.0  Iris-virginica
# 110                6.5               3.2  ...               2.0  Iris-virginica
# 139                6.9               3.1  ...               2.1  Iris-virginica
# 102                7.1               3.0  ...               2.1  Iris-virginica
# 112                6.8               3.0  ...               2.1  Iris-virginica
# 105                7.6               3.0  ...               2.1  Iris-virginica
# 124                6.7               3.3  ...               2.1  Iris-virginica
# 128                6.4               2.8  ...               2.1  Iris-virginica
# 117                7.7               3.8  ...               2.2  Iris-virginica
# 132                6.4               2.8  ...               2.2  Iris-virginica
# 104                6.5               3.0  ...               2.2  Iris-virginica
# 120                6.9               3.2  ...               2.3  Iris-virginica
# 115                6.4               3.2  ...               2.3  Iris-virginica
# 148                6.2               3.4  ...               2.3  Iris-virginica
# 141                6.9               3.1  ...               2.3  Iris-virginica
# 143                6.8               3.2  ...               2.3  Iris-virginica
# 145                6.7               3.0  ...               2.3  Iris-virginica
# 118                7.7               2.6  ...               2.3  Iris-virginica
# 135                7.7               3.0  ...               2.3  Iris-virginica
# 136                6.3               3.4  ...               2.4  Iris-virginica
# 140                6.7               3.1  ...               2.4  Iris-virginica
# 114                5.8               2.8  ...               2.4  Iris-virginica
# 100                6.3               3.3  ...               2.5  Iris-virginica
# 144                6.7               3.3  ...               2.5  Iris-virginica
# 109                7.2               3.6  ...               2.5  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
Iris.drop('SepalExtra', 1)
# Out:
#                    SepalWidthin(cm)  ...           Class
# SepalLength(incm)                    ...
# 5.1                             3.5  ...     Iris-setosa
# 4.9                             3.0  ...     Iris-setosa
# 4.7                             3.2  ...     Iris-setosa
# 4.6                             3.1  ...     Iris-setosa
# 5.0                             3.6  ...     Iris-setosa
# 5.4                             3.9  ...     Iris-setosa
# 4.6                             3.4  ...     Iris-setosa
# 5.0                             3.4  ...     Iris-setosa
# 4.4                             2.9  ...     Iris-setosa
# 4.9                             3.1  ...     Iris-setosa
# 5.4                             3.7  ...     Iris-setosa
# 4.8                             3.4  ...     Iris-setosa
# 4.8                             3.0  ...     Iris-setosa
# 4.3                             3.0  ...     Iris-setosa
# 5.8                             4.0  ...     Iris-setosa
# 5.7                             4.4  ...     Iris-setosa
# 5.4                             3.9  ...     Iris-setosa
# 5.1                             3.5  ...     Iris-setosa
# 5.7                             3.8  ...     Iris-setosa
# 5.1                             3.8  ...     Iris-setosa
# 5.4                             3.4  ...     Iris-setosa
# 5.1                             3.7  ...     Iris-setosa
# 4.6                             3.6  ...     Iris-setosa
# 5.1                             3.3  ...     Iris-setosa
# 4.8                             3.4  ...     Iris-setosa
# 5.0                             3.0  ...     Iris-setosa
# 5.0                             3.4  ...     Iris-setosa
# 5.2                             3.5  ...     Iris-setosa
# 5.2                             3.4  ...     Iris-setosa
# 4.7                             3.2  ...     Iris-setosa
# ...                             ...  ...             ...
# 6.9                             3.2  ...  Iris-virginica
# 5.6                             2.8  ...  Iris-virginica
# 7.7                             2.8  ...  Iris-virginica
# 6.3                             2.7  ...  Iris-virginica
# 6.7                             3.3  ...  Iris-virginica
# 7.2                             3.2  ...  Iris-virginica
# 6.2                             2.8  ...  Iris-virginica
# 6.1                             3.0  ...  Iris-virginica
# 6.4                             2.8  ...  Iris-virginica
# 7.2                             3.0  ...  Iris-virginica
# 7.4                             2.8  ...  Iris-virginica
# 7.9                             3.8  ...  Iris-virginica
# 6.4                             2.8  ...  Iris-virginica
# 6.3                             2.8  ...  Iris-virginica
# 6.1                             2.6  ...  Iris-virginica
# 7.7                             3.0  ...  Iris-virginica
# 6.3                             3.4  ...  Iris-virginica
# 6.4                             3.1  ...  Iris-virginica
# 6.0                             3.0  ...  Iris-virginica
# 6.9                             3.1  ...  Iris-virginica
# 6.7                             3.1  ...  Iris-virginica
# 6.9                             3.1  ...  Iris-virginica
# 5.8                             2.7  ...  Iris-virginica
# 6.8                             3.2  ...  Iris-virginica
# 6.7                             3.3  ...  Iris-virginica
# 6.7                             3.0  ...  Iris-virginica
# 6.3                             2.5  ...  Iris-virginica
# 6.5                             3.0  ...  Iris-virginica
# 6.2                             3.4  ...  Iris-virginica
# 5.9                             3.0  ...  Iris-virginica
#
# [150 rows x 4 columns]

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
IrisSubset = pd.DataFrame(Iris.iloc[0:10,0:3])
IrisSubset
# Out:
#    SepalLength(incm)  SepalWidthin(cm)  Petallength(incm)
# 0                5.1               3.5                1.4
# 1                4.9               3.0                1.4
# 2                4.7               3.2                1.3
# 3                4.6               3.1                1.5
# 4                5.0               3.6                1.4
# 5                5.4               3.9                1.7
# 6                4.6               3.4                1.4
# 7                5.0               3.4                1.5
# 8                4.4               2.9                1.4
# 9                4.9               3.1                1.5

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
file = "/content/drive/My Drive/PGML/labexternal-residency-I/HR_external.txt"
df = pd.read_csv(file, sep='\t')
df
# Out:
#      Individual  Attrition  ...  YearsSinceLastPromotion  YearsWithCurrManager
# 0           Ind1       Yes  ...                        0                     5
# 1           Ind2        No  ...                        1                     7
# 2           Ind3       Yes  ...                        0                     0
# 3           Ind4        No  ...                        3                     0
# 4           Ind5        No  ...                        2                     2
# 5           Ind6        No  ...                        3                     6
# 6           Ind7        No  ...                        0                     0
# 7           Ind8        No  ...                        0                     0
# 8           Ind9        No  ...                        1                     8
# 9          Ind10        No  ...                        7                     7
# 10         Ind11        No  ...                        0                     3
# 11         Ind12        No  ...                        0                     8
# 12         Ind13        No  ...                        4                     3
# 13         Ind14        No  ...                        1                     2
# 14         Ind15       Yes  ...                        0                     3
# 15         Ind16        No  ...                        8                     8
# 16         Ind17        No  ...                        0                     5
# 17         Ind18        No  ...                        0                     0
# 18         Ind19        No  ...                        3                     7
# 19         Ind20        No  ...                        1                     2
# 20         Ind21        No  ...                        1                     3
# 21         Ind22       Yes  ...                        0                     3
# 22         Ind23        No  ...                        2                    11
# 23         Ind24        No  ...                        0                     0
# 24         Ind25       Yes  ...                        1                     3
# 25         Ind26        No  ...                        4                     8
# 26         Ind27       Yes  ...                        6                     7
# 27         Ind28        No  ...                        4                     2
# 28         Ind29        No  ...                        5                    17
# 29         Ind30        No  ...                        2                     1
# ...          ...       ...  ...                      ...                   ...
# 1440     Ind1441        No  ...                        0                     2
# 1441     Ind1442        No  ...                        1                     9
# 1442     Ind1443       Yes  ...                        2                     2
# 1443     Ind1444        No  ...                        4                    14
# 1444     Ind1445       Yes  ...                        9                     8
# 1445     Ind1446        No  ...                        0                    10
# 1446     Ind1447        No  ...                        1                     7
# 1447     Ind1448        No  ...                       11                    11
# 1448     Ind1449        No  ...                        0                     4
# 1449     Ind1450        No  ...                        1                     2
# 1450     Ind1451        No  ...                        1                     7
# 1451     Ind1452        No  ...                        1                     9
# 1452     Ind1453       Yes  ...                        0                     1
# 1453     Ind1454        No  ...                        0                     0
# 1454     Ind1455        No  ...                        0                     1
# 1455     Ind1456        No  ...                        2                     2
# 1456     Ind1457        No  ...                        0                     2
# 1457     Ind1458        No  ...                        0                     2
# 1458     Ind1459        No  ...                        1                     1
# 1459     Ind1460        No  ...                        0                     3
# 1460     Ind1461        No  ...                        0                     4
# 1461     Ind1462       Yes  ...                        2                     0
# 1462     Ind1463        No  ...                        9                     6
# 1463     Ind1464        No  ...                        1                     7
# 1464     Ind1465        No  ...                        0                     0
# 1465     Ind1466        No  ...                        0                     3
# 1466     Ind1467        No  ...                        1                     7
# 1467     Ind1468        No  ...                        0                     3
# 1468     Ind1469        No  ...                        0                     8
# 1469     Ind1470        No  ...                        1                     2
#
# [1470 rows x 35 columns]

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
df.dtypes
# Out:
# Individual                  object
# Attrition                   object
# Age                          int64
# BusinessTravel               int64
# DailyRate                    int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                       int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                      int64
# JobSatisfaction              int64
# MaritalStatus                int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                     int64
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
df[df.columns[2:9]]
# Out:
#       Age  BusinessTravel  ...  Education  EducationField
# 0      41               1  ...          2               1
# 1      49               2  ...          1               1
# 2      37               1  ...          2               6
# 3      33               2  ...          4               1
# 4      27               1  ...          1               2
# 5      32               2  ...          2               1
# 6      59               1  ...          3               2
# 7      30               1  ...          1               1
# 8      38               2  ...          3               1
# 9      36               1  ...          3               2
# 10     35               1  ...          3               2
# 11     29               1  ...          2               1
# 12     31               1  ...          1               1
# 13     34               1  ...          2               2
# 14     28               1  ...          3               1
# 15     29               1  ...          4               1
# 16     32               1  ...          2               1
# 17     22               3  ...          2               2
# 18     53               1  ...          4               1
# 19     38               1  ...          3               1
# 20     24               3  ...          2               6
# 21     36               1  ...          4               1
# 22     34               1  ...          4               1
# 23     21               1  ...          2               1
# 24     34               1  ...          1               2
# 25     53               1  ...          3               6
# 26     32               2  ...          1               1
# 27     42               1  ...          4               3
# 28     44               1  ...          4               2
# 29     46               1  ...          4               3
# ...   ...             ...  ...        ...             ...
# 1440   36               2  ...          2               1
# 1441   56               3  ...          4               1
# 1442   29               1  ...          4               2
# 1443   42               1  ...          3               1
# 1444   56               1  ...          2               4
# 1445   41               1  ...          4               1
# 1446   34               1  ...          3               3
# 1447   36               3  ...          4               3
# 1448   41               1  ...          3               1
# 1449   32               1  ...          3               4
# 1450   35               1  ...          4               1
# 1451   38               1  ...          2               1
# 1452   50               2  ...          4               1
# 1453   36               1  ...          4               3
# 1454   45               1  ...          3               1
# 1455   40               1  ...          4               1
# 1456   35               2  ...          4               1
# 1457   40               1  ...          4               2
# 1458   35               1  ...          4               1
# 1459   29               1  ...          2               6
# 1460   29               1  ...          4               2
# 1461   50               1  ...          3               3
# 1462   39               1  ...          1               3
# 1463   31               3  ...          3               2
# 1464   26               1  ...          3               6
# 1465   36               2  ...          2               2
# 1466   39               1  ...          1               2
# 1467   27               1  ...          3               1
# 1468   49               2  ...          3               2
# 1469   34               1  ...          3               2
#
# [1470 rows x 7 columns]

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
df.groupby(['Gender']).size()
# Out:
# Gender
# 1    882
# 2    588
# dtype: int64

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
q1, q3= np.percentile(df['Age'], [25,75])
iqr = q3-q1
iqr
# Out:
# 13.0

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %%
meanD = df['DailyRate'].mean() 
medianD = df['DailyRate'].median()
varD = df['DailyRate'].var()
print("mean - %f, median - %f and variance - %f for the column - DailyRate"%(meanD,medianD,varD))
# Out:
# mean - 802.485714, median - 802.000000 and variance - 162819.593737 for the column - DailyRate

# %% [markdown]
# ### Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)

# %%
df['Attrition'].value_counts().plot(kind='bar')

# %% [markdown]
# ### Plot Total working years using matplotlib plot function

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(df['TotalWorkingYears'],'*')
