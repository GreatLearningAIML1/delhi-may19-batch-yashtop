# %% [markdown]
# ### The data set has information about features of silhouette extracted from the images of different cars
#
# Four "Corgie" model vehicles were used for the experiment: a double decker bus, Cheverolet van, Saab 9000 and an Opel Manta 400 cars. This particular combination of vehicles was chosen with the expectation that the bus, van and either one of the cars would be readily distinguishable, but it would be more difficult to distinguish between the cars.

# %% [markdown]
# ### 1. Read the dataset using function .dropna() - to avoid dealing with NAs as of now

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from scipy.stats import zscore
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.cluster import KMeans 
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
file = '/content/drive/My Drive/PGML/unsupervised/lab/vehicle.csv'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv(file)
df = df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df.head()
# Out:
#    compactness  circularity  ...  hollows_ratio  class
# 0           95         48.0  ...            197    van
# 1           91         41.0  ...            199    van
# 2          104         50.0  ...            196    car
# 3           93         41.0  ...            207    van
# 4           85         44.0  ...            183    bus
#
# [5 rows x 19 columns]

# %% [markdown]
# ### 2. Print/ Plot the dependent (categorical variable) - Class column

# %% [markdown]
# Since the variable is categorical, you can use value_counts function

# %%
data = df['class'].value_counts()
sns.barplot(data.index, data.values, alpha=0.8)
plt.title('Class data')
plt.ylabel('Count of Occurrences', fontsize=12)
plt.xlabel('Class', fontsize=12)
plt.show()

# %% [markdown]
# ### Check for any missing values in the data

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### 3. Standardize the data

# %%
df.drop('class', axis=1, inplace=True)

# %%
df_scaled = df.apply(zscore)

# %% [markdown]
# Since the dimensions of the data are not really known to us, it would be wise to standardize the data using z scores before we go for any clustering methods.
# You can use zscore function to do this

# %%
df_scaled
# Out:
#      compactness  circularity  ...  skewness_about.2  hollows_ratio
# 0       0.163231     0.520408  ...         -0.321809       0.171837
# 1      -0.322874    -0.619123  ...          0.003400       0.442318
# 2       1.256966     0.845988  ...         -0.159204       0.036596
# 3      -0.079822    -0.619123  ...          1.629444       1.524243
# 4      -1.052030    -0.130753  ...         -1.460039      -1.721531
# 6       0.406283    -0.293543  ...          1.792048       1.118521
# 7      -0.444400    -0.293543  ...          0.653818       0.848040
# 8      -0.930504    -1.758654  ...          1.792048       1.659484
# 10     -0.930504    -1.433074  ...          0.816422       0.848040
# 11     -0.444400    -1.758654  ...          1.141631       0.848040
# 12     -0.687452     0.194828  ...          0.003400      -0.098644
# 13     -0.565926    -0.456333  ...         -0.321809       0.171837
# 14      0.041705     0.683198  ...          1.304235       0.442318
# 15      0.284757     1.659939  ...         -0.484413      -0.233885
# 16     -0.565926    -1.433074  ...         -1.297435      -1.451050
# 17      0.649335    -0.619123  ...          1.466840       0.442318
# 18      1.256966     1.497149  ...         -0.647017      -0.098644
# 20     -1.173556     0.357618  ...         -0.647017      -0.504366
# 21     -1.173556    -1.270284  ...         -1.622644      -1.721531
# 22      0.041705    -0.293543  ...          1.629444       1.389003
# 23     -0.808978    -0.944703  ...          0.491213       0.442318
# 24      0.649335     1.334359  ...          0.328609       0.712800
# 25     -1.052030     0.032037  ...         -0.159204       0.442318
# 26     -1.295083    -1.433074  ...         -1.622644      -1.721531
# 27      1.621544     1.497149  ...         -0.321809       0.442318
# 28      1.013913     0.032037  ...          0.979026      -0.369125
# 29     -1.659661    -1.107494  ...         -1.460039      -1.451050
# 30     -0.565926    -0.293543  ...         -0.647017       0.036596
# 31     -0.687452    -0.456333  ...          1.466840       1.253762
# 32     -0.079822    -1.595864  ...          1.304235       0.848040
# ..           ...          ...  ...               ...            ...
# 816    -0.444400     0.520408  ...         -0.647017      -0.098644
# 817     1.256966     1.334359  ...          0.003400       0.983281
# 818     0.163231    -0.293543  ...          0.166004       0.171837
# 819    -0.079822    -0.456333  ...          0.003400       0.171837
# 820    -0.808978    -1.107494  ...         -1.297435      -1.315810
# 821     1.256966     1.822729  ...         -0.484413      -0.098644
# 822     0.163231    -0.619123  ...          1.629444       1.524243
# 823     1.378492     1.497149  ...          0.166004       0.307078
# 824     1.500018     1.659939  ...         -0.484413       0.036596
# 825    -0.930504    -0.944703  ...         -0.972226      -0.774847
# 826     0.163231     0.683198  ...          1.466840       1.389003
# 827     0.649335     1.985519  ...         -0.647017       0.307078
# 828    -0.565926    -0.456333  ...         -0.159204      -0.639607
# 829     0.163231     0.683198  ...         -1.134831      -0.639607
# 830     0.406283    -1.270284  ...          1.954653       1.659484
# 831     0.770861     0.357618  ...          1.792048       1.253762
# 832     1.743070     0.683198  ...          0.166004       0.442318
# 833    -0.201348     0.194828  ...         -0.484413      -0.639607
# 834    -1.416609    -1.433074  ...         -1.297435      -1.856772
# 835     2.107648     2.148309  ...         -1.297435      -1.721531
# 836    -0.808978     0.032037  ...         -0.159204       0.036596
# 837     0.041705     0.194828  ...          0.653818       0.442318
# 838     0.163231    -0.293543  ...         -0.321809       0.577559
# 839    -0.444400    -0.130753  ...          1.141631       0.983281
# 840    -0.079822    -1.758654  ...          1.954653       1.524243
# 841    -0.079822    -0.944703  ...         -0.159204      -0.098644
# 842    -0.565926     0.194828  ...         -0.484413       0.171837
# 843     1.500018     1.497149  ...         -0.321809       0.712800
# 844    -0.930504    -1.433074  ...          0.166004      -0.098644
# 845    -1.052030    -1.433074  ...         -0.484413      -0.774847
#
# [813 rows x 18 columns]

# %% [markdown]
# ### K - Means Clustering

# %% [markdown]
# ### 4. Assign a dummy array called distortion

# %%
distortion = []

# %% [markdown]
# You can later use this array to plot the elbow plot

# %% [markdown]
# ### 5. Calculating distortion - C distance

# %%
cluster_range = range( 1, 10 )
cluster_errors = []
for num_clusters in cluster_range:
  clusters = KMeans( num_clusters,n_init = 15, random_state=2)
  clusters.fit(df_scaled)
  labels = clusters.labels_
  centroids = clusters.cluster_centers_
  cluster_errors.append( clusters.inertia_ )
clusters_df = pd.DataFrame( { "num_clusters":cluster_range, "cluster_errors": cluster_errors } )
clusters_df[0:15]
# Out:
#    cluster_errors  num_clusters
# 0    14634.000000             1
# 1     8623.136976             2
# 2     7037.467395             3
# 3     5739.286384             4
# 4     5192.924772             5
# 5     4706.433256             6
# 6     4350.686420             7
# 7     4087.480072             8
# 8     3867.629387             9

# %% [markdown]
# Iterating values of k from 1 to 10 fit K means model
# Using c distance - Get the measure for Sum of squares error.

# %% [markdown]
# ### 6. Plotting Elbow/ Scree Plot

# %%
plt.figure(figsize=(12,6))
plt.plot( clusters_df.num_clusters, clusters_df.cluster_errors, marker = "o" )

# %% [markdown]
# Use Matplotlib to plot the scree plot - Note: Scree plot plots distortion vs the no of clusters

# %% [markdown]
# ### Find out the optimal value of K

# %%
# From the chart it is looks like, value of k should be between 2 to 6, but taking the value of k as 4

# %% [markdown]
# ### Using optimal value of K - Cluster the data.
# Note: Since the data has more than 2 dimension we cannot visualize the data. As an alternative, we can observe the centroids and note how they are distributed across different dimensions

# %%
kmeans = KMeans(n_clusters=4)
kmeans.fit(df_scaled)
# Getting the cluster labels
labels = kmeans.predict(df_scaled)
# Centroid values
centroids = kmeans.cluster_centers_
# Comparing with scikit-learn centroids
print("Centroid values")
print("sklearn")
print(centroids) # From sci-kit learn
# Out:
# Centroid values
# sklearn
# [[-0.33496591 -0.86857277 -0.53672369 -0.24994725  0.07133146 -0.21649273
#   -0.69359446  0.60492273 -0.71048445 -0.79359254 -0.66271211 -0.66968046
#   -0.91576547 -0.76667236 -0.12614553  0.04059587  1.01947533  0.86082405]
#  [ 0.16484024  0.10750306  0.2861306   0.70102101  0.73720241  0.42581548
#    0.16303684 -0.36118688  0.10990587  0.06777262  0.32828631  0.11123963
#    0.0981574  -0.14746118  0.02003632 -0.0095195   0.48152163  0.40649296]
#  [-0.92021373 -0.50359469 -0.86269296 -1.05424149 -0.5294184  -0.31448232
#   -0.76417293  0.83748992 -0.73458945 -0.48044093 -0.78034055 -0.76953567
#   -0.37368879  0.74901857 -0.10103691 -0.31345186 -1.01812269 -1.07095865]
#  [ 1.27065858  1.329773    1.30809199  0.96637143  0.02648158  0.26858458
#    1.42867987 -1.28989555  1.4478393   1.26022434  1.30121294  1.44907715
#    1.22968034 -0.04407898  0.22247381  0.33339782 -0.11798066  0.14643978]]

# %% [markdown]
# You can use kmeans.cluster_centers_ function to pull the centroid information from the instance

# %% [markdown]
# ### 7. Store the centroids in a dataframe with column names from the original dataset given

# %%
prediction= kmeans.predict(df_scaled)
#X["clusters"] = prediction
X_df = pd.DataFrame(df_scaled, columns=list(df_scaled))
X_df
# Out:
#      compactness  circularity  ...  skewness_about.2  hollows_ratio
# 0       0.163231     0.520408  ...         -0.321809       0.171837
# 1      -0.322874    -0.619123  ...          0.003400       0.442318
# 2       1.256966     0.845988  ...         -0.159204       0.036596
# 3      -0.079822    -0.619123  ...          1.629444       1.524243
# 4      -1.052030    -0.130753  ...         -1.460039      -1.721531
# 6       0.406283    -0.293543  ...          1.792048       1.118521
# 7      -0.444400    -0.293543  ...          0.653818       0.848040
# 8      -0.930504    -1.758654  ...          1.792048       1.659484
# 10     -0.930504    -1.433074  ...          0.816422       0.848040
# 11     -0.444400    -1.758654  ...          1.141631       0.848040
# 12     -0.687452     0.194828  ...          0.003400      -0.098644
kmeans = KMeans(n_clusters=4,n_init=15, random_state=2)
kmeans.fit(df_scaled)
centroids=kmeans.cluster_centers_
centroid_df = pd.DataFrame(centroids, columns = list(df_scaled) )
centroid_df
# Out:
#    compactness  circularity  ...  skewness_about.2  hollows_ratio
# 0     1.154428     1.184286  ...          0.004670       0.190327
# 1    -0.916833    -0.526197  ...         -1.043366      -1.099425
# 2    -0.225338    -0.574343  ...          0.824842       0.707985
# 3    -0.733024     0.072735  ...         -0.707994      -0.453651
#
# [4 rows x 18 columns]

# %% [markdown]
# ### Use kmeans.labels_ function to print out the labels of the classes

# %%
df_labels = pd.DataFrame(kmeans.labels_ , columns = list(['labels']))

df_labels['labels'] = df_labels['labels'].astype('category')
df_labeled = df_scaled.join(df_labels)

# %%
df_labeled
# Out:
#      compactness  circularity  ...  hollows_ratio  labels
# 0       0.163231     0.520408  ...       0.171837       2
# 1      -0.322874    -0.619123  ...       0.442318       2
# 2       1.256966     0.845988  ...       0.036596       0
# 3      -0.079822    -0.619123  ...       1.524243       2
# 4      -1.052030    -0.130753  ...      -1.721531       3
# 6       0.406283    -0.293543  ...       1.118521       2
# 7      -0.444400    -0.293543  ...       0.848040       2
# 8      -0.930504    -1.758654  ...       1.659484       2
# 10     -0.930504    -1.433074  ...       0.848040       2
# 11     -0.444400    -1.758654  ...       0.848040       2
# 12     -0.687452     0.194828  ...      -0.098644       2
# 13     -0.565926    -0.456333  ...       0.171837       0
# 14      0.041705     0.683198  ...       0.442318       1
# 15      0.284757     1.659939  ...      -0.233885       2
# 16     -0.565926    -1.433074  ...      -1.451050       0
# 17      0.649335    -0.619123  ...       0.442318       1
# 18      1.256966     1.497149  ...      -0.098644       1
# 20     -1.173556     0.357618  ...      -0.504366       2
# 21     -1.173556    -1.270284  ...      -1.721531       0
# 22      0.041705    -0.293543  ...       1.389003       2
# 23     -0.808978    -0.944703  ...       0.442318       1
# 24      0.649335     1.334359  ...       0.712800       0
# 25     -1.052030     0.032037  ...       0.442318       0
# 26     -1.295083    -1.433074  ...      -1.721531       1
# 27      1.621544     1.497149  ...       0.442318       2
# 28      1.013913     0.032037  ...      -0.369125       2
# 29     -1.659661    -1.107494  ...      -1.451050       2
# 30     -0.565926    -0.293543  ...       0.036596       0
# 31     -0.687452    -0.456333  ...       1.253762       2
# 32     -0.079822    -1.595864  ...       0.848040       1
# ..           ...          ...  ...            ...     ...
# 816    -0.444400     0.520408  ...      -0.098644     NaN
# 817     1.256966     1.334359  ...       0.983281     NaN
# 818     0.163231    -0.293543  ...       0.171837     NaN
# 819    -0.079822    -0.456333  ...       0.171837     NaN
# 820    -0.808978    -1.107494  ...      -1.315810     NaN
# 821     1.256966     1.822729  ...      -0.098644     NaN
# 822     0.163231    -0.619123  ...       1.524243     NaN
# 823     1.378492     1.497149  ...       0.307078     NaN
# 824     1.500018     1.659939  ...       0.036596     NaN
# 825    -0.930504    -0.944703  ...      -0.774847     NaN
# 826     0.163231     0.683198  ...       1.389003     NaN
# 827     0.649335     1.985519  ...       0.307078     NaN
# 828    -0.565926    -0.456333  ...      -0.639607     NaN
# 829     0.163231     0.683198  ...      -0.639607     NaN
# 830     0.406283    -1.270284  ...       1.659484     NaN
# 831     0.770861     0.357618  ...       1.253762     NaN
# 832     1.743070     0.683198  ...       0.442318     NaN
# 833    -0.201348     0.194828  ...      -0.639607     NaN
# 834    -1.416609    -1.433074  ...      -1.856772     NaN
# 835     2.107648     2.148309  ...      -1.721531     NaN
# 836    -0.808978     0.032037  ...       0.036596     NaN
# 837     0.041705     0.194828  ...       0.442318     NaN
# 838     0.163231    -0.293543  ...       0.577559     NaN
# 839    -0.444400    -0.130753  ...       0.983281     NaN
# 840    -0.079822    -1.758654  ...       1.524243     NaN
# 841    -0.079822    -0.944703  ...      -0.098644     NaN
# 842    -0.565926     0.194828  ...       0.171837     NaN
# 843     1.500018     1.497149  ...       0.712800     NaN
# 844    -0.930504    -1.433074  ...      -0.098644     NaN
# 845    -1.052030    -1.433074  ...      -0.774847     NaN
#
# [813 rows x 19 columns]

# %% [markdown]
# ## Hierarchical Clustering

# %% [markdown]
# ### 8. Variable creation

# %% [markdown]
# *For* Hierarchical clustering, we will create datasets using multivariate normal distribution to visually observe how the clusters are formed at the end

# %%
a = np.random.multivariate_normal([10,0],[[3,1],[1,4]],size=[100,])
b = np.random.multivariate_normal([0,20],[[3,1],[1,4]],size=[50,])
c = np.random.multivariate_normal([10,20],[[3,1],[1,4]],size=[100,])

# %% [markdown]
# a = np.random.multivariate_normal([10, 0], [[3, 1], [1, 4]], size=[100,])
# b = np.random.multivariate_normal([0, 20], [[3, 1], [1, 4]], size=[50,])
# c = np.random.multivariate_normal([10, 20], [[3, 1], [1, 4]], size=[100,])

# %% [markdown]
# ### 9. Combine all three arrays a,b,c into a dataframe

# %%
d = np.concatenate([a,b,c])
data = pd.DataFrame(d,columns=['f1','f2'])
data.head()
# Out:
#           f1        f2
# 0   8.183977 -1.846841
# 1  10.777178 -0.903384
# 2   7.390570 -2.738320
# 3  11.351860  0.503465
# 4   9.658592  2.025870

# %% [markdown]
# ### 10. Use scatter matrix to print all the 3 distributions

# %%
sns.pairplot(data)

# %% [markdown]
# ### 11. Find out the linkage matrix

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.spatial.distance import pdist

Z = linkage(data, 'ward')
Z
# Out:
# array([[1.41000000e+02, 1.45000000e+02, 2.71688808e-02, 2.00000000e+00],
#        [1.57000000e+02, 2.03000000e+02, 3.00219256e-02, 2.00000000e+00],
#        [2.06000000e+02, 2.08000000e+02, 6.31330256e-02, 2.00000000e+00],
#        [4.30000000e+01, 7.60000000e+01, 6.58701881e-02, 2.00000000e+00],
#        [3.00000000e+00, 2.60000000e+01, 6.98822537e-02, 2.00000000e+00],
#        [1.08000000e+02, 2.50000000e+02, 7.41380151e-02, 3.00000000e+00],
#        [1.20000000e+02, 1.32000000e+02, 7.65834259e-02, 2.00000000e+00],
#        [2.46000000e+02, 2.49000000e+02, 7.68162666e-02, 2.00000000e+00],
#        [1.52000000e+02, 2.12000000e+02, 9.14309351e-02, 2.00000000e+00],
#        [3.00000000e+01, 3.20000000e+01, 1.09452722e-01, 2.00000000e+00],
hierarchical Clustering Dendogram')
plt.xlabel('sample index')
plt.ylabel('Distance')
dendrogram(Z,leaf_rotation=90.0,p=4,color_threshold=12,leaf_font_size=10,truncate_mode='level')
plt.tight_layout()

# %% [markdown]
# ### 13. Recreate the dendrogram for last 12 merged clusters

# %%
plt.figure(figsize=(18, 16))
plt.title('Agglomerative Hierarchical Clustering Dendogram')
plt.xlabel('sample index')
plt.ylabel('Distance')
dendrogram(Z,leaf_rotation=90.0,p=12,color_threshold=12,leaf_font_size=10,truncate_mode='lastp')
plt.tight_layout()

# %% [markdown]
# Hint: Use truncate_mode='lastp' attribute in dendrogram function to arrive at dendrogram

# %% [markdown]
# ### 14. From the truncated dendrogram, find out the optimal distance between clusters which u want to use an input for clustering data

# %%
# optimal distnace should be 50

# %% [markdown]
# ### 15. Using this distance measure and fcluster function to cluster the data into 3 different groups

# %%
from scipy.cluster.hierarchy import fcluster

max_d = 50
clusters = fcluster(Z, max_d, criterion='distance')
final_df = data
final_df['cluster'] = clusters

final_df
# Out:
#             f1         f2  cluster
# 0     8.183977  -1.846841        1
# 1    10.777178  -0.903384        1
# 2     7.390570  -2.738320        1
# 3    11.351860   0.503465        1
# 4     9.658592   2.025870        1
# 5    11.373759   1.042409        1
# 6     9.345760   1.028528        1
# 7    12.203630   1.979940        1
# 8     9.730582  -1.170462        1
# 9    10.820413  -1.876284        1
# 10    7.258049  -2.691608        1
# 11   11.785421   0.236888        1
# 12    8.427241  -2.284233        1
# 13   10.798427  -0.406541        1
# 14    9.871776   3.324374        1
# 15    7.823657  -0.803900        1
# 16    9.180291   0.458607        1
# 17    9.645704  -0.225682        1
# 18    6.957201  -1.566038        1
# 19   13.163022   0.604204        1
# 20   10.037703  -0.264130        1
# 21   12.915655   0.112476        1
# 22   11.640324   1.404311        1
# 23   11.972911  -1.860993        1
# 24   10.619025   1.513088        1
# 25   11.610582   0.239529        1
# 26   11.391981   0.446247        1
# 27   10.701838   1.403979        1
# 28   14.048669  -0.843975        1
# 29   10.030136  -0.869184        1
# ..         ...        ...      ...
# 220   9.216073  17.576635        3
# 221   7.583500  21.385158        3
# 222   9.918942  21.305283        3
# 223   6.507811  19.305721        3
# 224  12.422745  23.066847        3
# 225   7.845249  21.132864        3
# 226   9.528229  14.376456        3
# 227  13.127524  20.548603        3
# 228  11.571014  24.253891        3
# 229  11.508190  18.032107        3
# 230  12.261744  20.321220        3
# 231   8.528542  19.225683        3
# 232   8.774084  20.566701        3
# 233  10.291008  18.312028        3
# 234  10.461956  16.901324        3
# 235   7.719750  20.143311        3
# 236  11.966207  17.043780        3
# 237   8.980522  20.687590        3
# 238  10.936642  23.164257        3
# 239   9.507574  19.896309        3
# 240  11.526679  21.954191        3
# 241  11.391219  20.096255        3
# 242   9.676380  17.967678        3
# 243   6.860562  18.593229        3
# 244   9.573911  18.960900        3
# 245  11.901540  19.908303        3
# 246  10.149493  19.667619        3
# 247  10.011994  19.978842        3
# 248  10.731603  20.099011        3
# 249  10.213788  19.625584        3
#
# [250 rows x 3 columns]

# %% [markdown]
# ### Use matplotlib to visually observe the clusters in 2D space

# %%
sns.pairplot(final_df)
